# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore

# %%
data=pd.read_csv('Supermart Grocery Sales - Retail Analytics Dataset.csv')

# %%
data['Z_Score'] = zscore(data['Sales'])
outliers = data[data['Z_Score'].abs() > 3]
print(outliers)
# Out:
# Empty DataFrame
# Columns: [Order ID, Customer Name, Category, Sub Category, City, Order Date, Region, Sales, Discount, Profit, State, Z_Score]
# Index: []

# %%
sns.boxplot(x=data['Sales'])
plt.title('Sales Distribution (Boxplot)')
plt.xlabel('Sales')
plt.show()
