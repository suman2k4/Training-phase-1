# %%
# !rm -rf .zen
# !zenml init
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.
# ⠋ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠙ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠹ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠸ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠴ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠦ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠧ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠇ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# Training\Phase 1\New folder.
#
# ⠏ Initializing ZenML repository at c:\Users\ASLAM\Desktop\Syncner
# ...
